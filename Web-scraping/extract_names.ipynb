# %%
import spacy
import requests
import pandas as pd
from bs4 import BeautifulSoup
from pprint import pprint

# Using CODING and ALGORITHMS to detect names
nlp = spacy.load('en_core_web_sm')

# %%
url = r'https://uwaterloo.ca/mechanical-mechatronics-engineering/about/people/group/117'
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()    # rip it out

text = soup.get_text().split('\n')

# %%
profs = []
for line in text:
    # Classify words in each line using NEURAL NETWORKS
    doc = nlp(line)
    profName = ''
    for token in doc:        
        if token.pos_ == 'PROPN':
            profName = profName + ' ' + token.text
    if profName != '':
        profs.append(profname)
    print(profName)
# Out:
#  | Mechanical Mechatronics Engineering | University Waterloo
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Information
#
#
#
#
#
#  University Waterloo
#
#
#
#
#  Waterloo
#
#
#  Waterloo
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Mechatronics Engineering
#  Mechanical Mechatronics Engineering
#
#  ResearchCanada Research Chairs
#
#
#
#
#  | ServicesInformation Technology
#  MME ClinicActivities
#
#
#
#
#
#
#
#
#
#
#
#
#  Health SafetyBulletin Board
#
#
#  Incident Report
#
#
#
#
#  EngineeringProgram
#
#  Welding Joining Specialization
#
#
#
#
#  Mechatronics EngineeringProgram
#
#
#
#
#
#  EngineeringSchedules
#
#
#  Joining Specialization
#
#  Mechanical Engineering
#
#
#  Mechatronics EngineeringSchedules
#  Academic Issues
#  Options
#
#
#
#
#
#
#
#
#  studentsHow
#
#  MEng
#
#  Nanotechnology
#
#
#
#
#
#  Master Engineering MEng
#  Master Applied Science
#  Philosophy
#
#
#  Addendum Faculty Performance Evaluation
#
#
#
#
# ...

# %%
profs
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...
